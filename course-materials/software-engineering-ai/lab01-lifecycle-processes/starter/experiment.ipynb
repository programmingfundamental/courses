# %% [markdown]
# # Монолитен експеримент — AI Prediction Platform
# Само synthetic данни. TODO: backlog, lifecycle, конфигурация, архитектура и tests.
# Стартирайте kernel в тази starter папка. Hardcoded path е умишлен code smell.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
data = pd.read_csv('../../ai-platform/data/requests-v1.csv')
x = data[['token_count', 'keyword_score', 'previous_requests']]
scaler = StandardScaler()
x = scaler.fit_transform(x)
model = LogisticRegression(C=10, random_state=42, max_iter=300)
model.fit(x, data.label)
print('Training score (not acceptance quality):', model.score(x, data.label))
print('Prediction:', model.predict(x[:1]).tolist())
# TODO: data identity, held-out validation, configuration, artifact version, tests.
